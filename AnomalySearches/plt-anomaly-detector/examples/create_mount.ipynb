# %%
import sys
sys.path.append("..")

# %%
from src.data.mounting_tool import MountData

# %%
mounter = MountData(user=".", password=".")

# %%
mounter.create_mount(mount_source="brildev1:/brildata/22/", mount_target="./Files/22")
# Out:
# Mount target is not a directory. Creating it...
